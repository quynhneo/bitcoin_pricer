# %%
run test.py
# Out:
# data/finance_data.csv finance data file exists and will be loaded
# data/google_trend_data.csv : Google trend data file exist and will be loaded
# model/LinearRegression.mdl model file exists and loaded
# started model
# loading additional data from  2020-11-02 00:00:00 to,  2020-11-06 18:37:06.463224
# overlap 2020-11-02T00:00:00.000000000
# finish training
# Given ^GSPC =  3319.47 , ^VIX =  25.83 ,Volume =  22825594880 ,Google Trend bitcoin = 65
# Predicted price of Bitcoin: [10417.45823488]
# loading additional data from  2020-11-02 00:00:00 to,  2020-11-06 18:37:06.952427
# overlap 2020-11-02T00:00:00.000000000
# R^2 score:  0.8079341262043429
